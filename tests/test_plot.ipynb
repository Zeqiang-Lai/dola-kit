# %%
import dola

dola.imshow(dola.examples.color)

# %%
img = dola.plot.add_text(dola.examples.color, 'hello')
dola.imshow(img)

# %%
img = dola.examples.color
print(img.shape)
img = dola.imresize(img, (128, 256))
dola.imshow(img)
# Out:
# (768, 1024, 3)
